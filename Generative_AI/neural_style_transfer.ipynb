# %% [markdown]
# # Neural Style Transfer (NST)
#
# "The process of NST assumes an input image p and an example style image a.
# The image p is fed through a pretrained CNN, and network activations are sampled at a late convolution layer of the CNN architecture (original paper used VGG-19). Let C(p) be the resulting output sample, called the 'content' of the input p.
# The style image a is then fed through the same CNN, and network activations are sampled at the early to middle layers of the CNN. These activations are encoded into a Gramian matrix representation, call it S(a) to denote the 'style' of a.
# The goal of NST is to synthesize an output image x that exhibits the content of p applied with the style of a, i.e. C(x)=C(p) and S(x)=S(a).
# An iterative optimization (usually gradient descent) then gradually updates x to minimize the loss function error:
# L(x)=∣C(x)−C(p)∣+k∣S(x)−S(a)∣, where ∣⋅∣ is the L2 distance. The constant k controls the level of the stylization effect." ("Neural style transfer", 2023)

# %%
import numpy as numpy
import matplotlib.pyplot as plt
import torch
import torchvision
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

x = torch.rand(3, 224, 224).to(device) 
x.requires_grad = True # to optimize it with GD
p = torchvision.io.read_image(path = "../datasets/NST/profile_pic.jpg").to(device).type(torch.float32)/255.0
a = torchvision.io.read_image(path = "../datasets/NST/mosaic_style.jpg").to(device).type(torch.float32)/255.0

#resize images to fit expected VGG dimensions
p = torchvision.transforms.functional.resize(img = p, size = [224, 224], interpolation = torchvision.transforms.InterpolationMode.BILINEAR)
a = torchvision.transforms.functional.resize(img = a, size = [224, 224], interpolation = torchvision.transforms.InterpolationMode.BILINEAR)

#show both images next to each other:
plt.figure(figsize = (10, 10))
plt.subplot(1, 3, 1)
plt.title("x: random noise")
plt.imshow(x.permute(1, 2, 0).cpu().detach().numpy())
plt.subplot(1, 3, 2)
plt.title("p: content image")
plt.imshow(p.permute(1, 2, 0).cpu().detach().numpy())
plt.subplot(1, 3, 3)
plt.title("a: style image")
plt.imshow(a.permute(1, 2, 0).cpu().detach().numpy())
# Out:
# c:\Users\s_gue\anaconda3\envs\ml_basics\Lib\site-packages\torchvision\transforms\functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %% [markdown]
# The original paper used VGG19 to extract content and style features as follows:
# "The images [...] were synthesised by matching the content representation on layer ‘conv4_2’ (amounts to layer 21)
# and the style representation on layers‘conv1_1’ (layer 0), ‘conv2_1’ (layer 5), ‘conv3_1’ (layer 10), ‘conv4_1’ (layer 19) and ‘conv5_1’ (layer 28)
# (w_l = 1/5 in those layers, wl = 0 in all other layers)." (p.6 - layer numbers were added)
#
# --> Early layers tend to capture gradients and textures, while later layers tend towards more complex types of feature.
#
# The Neural Style Transfer loss:
# "First, content and style features are extracted and stored. The style image $a$ is passed through the network, and its style representation $A_l$ on all layers included are computed and stored (left). The content image $p$ is passed through the network, and the content representation $P_l$ in one layer is stored (right). Then, a random white noise image $x$ is passed through the network, and its style features $G_l$ and content features $F_l$ are computed. On each layer included in the style representation, the element-wise mean squared difference between $G_l$ and $A_l$ is computed to give the style loss $L_{\text{style}}$ (left). Also, the mean squared difference between $F_l$ and $P_l$ is computed to give the content loss $L_{\text{content}}$ (right). The total loss $L_{\text{total}}$ is then a linear combination between the content and the style loss." (Gatys, Ecker & Bethge, 2016, p.4)
#
# ![image](./files/Gatys_2016.png)
# (Gatys, Ecker & Bethge, 2016)
#
# Notes:
# - We use the VGG19 model to extract features from the images (as used in the orig. paper)
# - The intermediate values for the layers can be obtained using forward hooks
# - We need to get the intermediate features of p and a only once (therefore in the init of the loss)
# - The intermediate features of x need to be computed every time the loss is called (i.e. in the forward of the loss)

# %%
#Let's first look at the model to determine the layers:
import torchvision.models as models
vgg19 = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1)
vgg19.eval() # freeze the model
vgg19.to(device) # move the model to GPU

vgg19
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
from torch import Tensor
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import pytorch_lightning as pl
import torchvision.models as models
from typing import List

# Create a callable for the hooks
class Get_Layer_Output:
 def __init__(self):
    self.outputs = []

 def __call__(self, module, module_in, module_out):
    self.outputs.append(module_out)

 def clear(self):
    self.outputs = []


class NST_Loss(nn.Module):
    def __init__(
            self, 
            p: Tensor, 
            a: Tensor, 
            p_layers: List, 
            a_layers: List,
            alpha: float = 1.0, #content weight
            beta: float = 1.0 #style weight
            ):
        super().__init__()

        self.alpha = alpha
        self.beta = beta

        # Load the pretrained VGG19 model
        self.vgg19 = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1)
        self.vgg19.eval() # freeze the model
        self.vgg19.to(device) # move the model to GPU

        # Disable grad (otherwise the NST model will try to step through it as well)
        for param in self.vgg19.features.parameters():
            param.requires_grad = False

        #Add extra dim for VGG19
        p[None,...]
        a[None,...]
        
        # Add hooks to the model to extract layer outputs
        self.get_layer_output_p = Get_Layer_Output()
        self.get_layer_output_a = Get_Layer_Output()
        for layer in self.vgg19.features.children():
            if not p_layers and not a_layers:
                break  # Stop iterating once all specified layers are found
            if isinstance(layer, torch.nn.modules.conv.Conv2d):
                if p_layers and layer == self.vgg19.features[p_layers[0]]:
                    layer.register_forward_hook(self.get_layer_output_p)
                    #hook_handles.append(handle)
                    p_layers.pop(0)
                elif a_layers and layer == self.vgg19.features[a_layers[0]]:#
                    layer.register_forward_hook(self.get_layer_output_a)
                    a_layers.pop(0)
        
        dummy_out = self.vgg19(p) #run with p to get p features
        self.p_features = self.get_layer_output_p.outputs 
        self.num_p_layers = len(self.p_features)
        self.get_layer_output_a.clear() #clear hook outputs
        dummy_out = self.vgg19(a) #run with a to get a features
        self.a_features = self.get_layer_output_a.outputs
        self.num_a_layers = len(self.a_features)
        self.get_layer_output_p.clear()
        self.get_layer_output_a.clear()

    def forward(self, x: Tensor) -> Tensor:
        #Get x features
        x[None,...]
        model_out = self.vgg19(x)
        p_loss = sum([(self.p_features[i] - self.get_layer_output_p.outputs[i]).pow(2).mean()*(1/self.num_p_layers) for i in range(self.num_p_layers)])
        a_loss = sum([(self.a_features[i] - self.get_layer_output_a.outputs[i]).pow(2).mean()*(1/self.num_a_layers) for i in range(self.num_a_layers)])
        self.get_layer_output_p.clear()
        self.get_layer_output_a.clear()
        return self.alpha*p_loss + self.beta*a_loss

# %% [markdown]
# Now, lets create the model and a dummy dataset. The model only takes a random noise image (x) as input and we make it a parameter such that it can be updated.
# The training will only consist of handing x to the NST_Loss and updating it based on the difference of its features to the features of the content (p) and style image (a).
# Note: We create a dummy dataset because the PL Trainer expects that as input. Additionally, we add a Callback that will only grab the final tuned input image and plot it.

# %%
from pytorch_lightning.callbacks import Callback

class Show_Result(Callback):
    def on_train_end(self, trainer, pl_module):
        plt.imshow(pl_module.x.permute(1, 2, 0).cpu().detach().numpy())


class NST_model(pl.LightningModule):
    def __init__(self, x, p, a, alpha: float = 1.0, beta: float = 1.0, lr = 0.01):
        super().__init__()
        self.x = nn.Parameter(x.clone()) #nn.Parameter specifies that this is an updateable parameter
        self.lr = lr
        self.NST_loss = NST_Loss(
            p = p, 
            a = a, 
            p_layers = [21], 
            a_layers = [0, 5, 10, 19, 28],
            alpha = alpha, #content weight
            beta = beta #style weight
            )
        
    def forward(self):
        return self.x
    
    def training_step(self, batch, batch_idx):
        loss = self.NST_loss(self.x)
        print(loss)
        #plt.imshow(self.x.permute(1, 2, 0).cpu().detach().numpy())
        return loss

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr)


class NST_dataset(Dataset):
    def __init__(self):
        pass
    def __len__(self):
        return 1
    def __getitem__(self, idx):
        return 0

# %% [markdown]
# Normalize all images as expected by VGG19

# %%
transform = torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
x = transform(x)
p = transform(p)
a = transform(a)

# %% [markdown]
# Let's train to obtain an image that has the content and style we aim for.

# %%
model = NST_model(x, p, a, alpha = 1.0, beta = 1.0, lr = 0.3)
dataset = NST_dataset()
trainer = pl.Trainer(max_epochs=120, callbacks=[Show_Result()])
dataloader = DataLoader(dataset, batch_size=1)
trainer.fit(model, dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type     | Params
# ------------------------------------------
# 0 | NST_loss     | NST_Loss | 143 M
#   | other params | n/a      | 150 K
# ------------------------------------------
# 123 M     Trainable params
# 20.0 M    Non-trainable params
# 143 M     Total params
# 575.271   Total estimated model params size (MB)
# c:\Users\s_gue\anaconda3\envs\ml_basics\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:441: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=19` in the `DataLoader` to improve performance.
# c:\Users\s_gue\anaconda3\envs\ml_basics\Lib\site-packages\pytorch_lightning\loops\fit_loop.py:293: The number of training batches (1) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s] tensor(386.8879, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(332.1081, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(307.2995, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(284.9566, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(269.1803, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(255.7905, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(245.8597, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(236.3973, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(227.8451, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(220.1909, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]       tensor(213.6147, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(207.5177, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(202.0766, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(197.2094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(192.5105, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(188.0137, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(183.9635, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(179.9240, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(176.3318, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(172.9649, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(169.8376, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(167.0691, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(164.6615, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(162.1158, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(159.5654, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(157.4727, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(155.3852, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(153.4147, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(151.5839, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(150.2086, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(148.7513, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(147.2185, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(146.0190, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(144.4694, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(143.3411, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(142.4997, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(141.7044, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(141.1869, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(140.4784, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(139.4839, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(138.6473, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(138.2064, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(137.7980, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(137.3295, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(136.5869, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(135.8801, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(135.2832, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(135.5218, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(135.5705, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 49:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(134.6999, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(134.3087, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 51:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(133.8944, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(133.2866, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(132.8399, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(132.5484, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(132.4727, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(132.2414, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(131.6063, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(131.5531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(131.1215, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 60:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(131.1305, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 61:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(130.7935, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(130.8763, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 63:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(130.7875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(130.7807, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(130.3452, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(130.0148, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 67:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(129.8821, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(129.4296, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(129.2296, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(129.2361, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(128.9413, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(128.6207, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 73:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(128.5556, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 74:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(128.2916, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.7536, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.7019, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 77:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.5719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.5730, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.6270, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 80:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.5230, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.3223, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.6329, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(127.1424, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.8326, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.8331, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.6124, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.5122, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.7319, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.8246, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.3696, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.3508, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(126.0606, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.9268, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.8246, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.7589, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.7485, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.4952, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.3556, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.3819, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 100:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]       tensor(125.1675, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 101:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.2334, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 102:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(125.1459, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 103:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.7658, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 104:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.6934, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 105:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.6750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 106:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.4060, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 107:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.3137, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 108:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.1006, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 109:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.4258, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 110:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.8120, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 111:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.6583, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 112:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.4975, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 113:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.5800, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 114:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.6365, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 115:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.6172, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 116:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.5921, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 117:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(124.0318, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 118:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(123.8140, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 119:   0%|          | 0/1 [00:00<?, ?it/s, v_num=37]        tensor(123.9597, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 119: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s, v_num=37]
# `Trainer.fit` stopped: `max_epochs=120` reached.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Epoch 119: 100%|██████████| 1/1 [00:01<00:00,  0.60it/s, v_num=37]

# %% [markdown]
# Seems to go in the right direction... however, we left one additionaly feature out that the original paper used.
# Namely, when we compare the feature maps for the style loss from early layers, we do not get a perfect result as these feature maps encode information spatially. We rather want to know how the existing style features co-occur, regardless of where they occur in the image.
#
# For this, the authors employed a Gram Matrix which captures the correlation between the style features. "A layer with $N_l$ distinct filters has $N_l$ feature maps, each of size $M_l$, where $M_l$ is the height times the width of the feature map. So the responses in a layer $l$ can be stored in a matrix $F^l \in \mathbb{R}^{N_l \times M_l}$, where $F^l_{ij}$ is the activation of the $i$-th filter at position $j$ in layer $l$. [...]
# [The Gram Matrix] feature space can be built on top of the filter responses in any layer of the network. It consists of the correlations between the different filter responses, where the expectation is taken over the spatial extent of the feature maps. These feature correlations are given by the Gram matrix $G_l \in \mathbb{R}^{N_l \times N_l}$, where $G_{l,ij}$ is the inner product between the vectorized feature maps $i$ and $j$ in layer $l$:
# \begin{equation}
# G_{l,ij} = \sum_{k} F_{l,ik} \cdot F_{l,jk}
# \end{equation}
# By including the feature correlations of multiple layers, we obtain a stationary, multi-scale representation of the input
# image, which captures its texture information but not the global arrangement." (p. )
#
# --> essentially, this means we use the loss between the Gram matrices of the style image (a) and the input image (x).

# %% [markdown]
# Lets create a function that calculates the Gram Matrix.
# The features have the following dimensions: [batch_size, num_features, height, width] or [bfhw]
# We need to take a dot product of the features. Therefore we:
# - need to get rid of the b dimension -> suqeeze first dimension to get F = [fhw]
# - flatten the h and w dimension -> we get a dimension of F = [fk] where k is the flattened hw dimensions
# - multiply the resulting matrix with itself (F @ F.T) -> G = [ff]

# %%
#The Gram Matrix can be computed in one line using torch.einsum.
#To foster understanding, we will first do a more intuitive implementation:

#The intuitive version
# def gram_matrix(feature: Tensor) -> Tensor:
#     """
#     Computes the Gram matrix of a given feature map.
#     Args:
#         feature: Tensor of shape (B, F, H, W) where F is the number of features, H the height of the feature map and W the width of the feature map.
#     Returns:
#         The Gram matrix of the feature map of shape (F, F)
#     """
#     feature = feature.squeeze(0) #remove batch dimension
#     feature = feature.flatten(1) #flatten feature map
#     return feature @ feature.T #compute gram matrix


#The einsum version + normalization
def gram_matrix(feature: Tensor) -> Tensor:
    feature = torch.einsum("bfhw,bghw->fg", feature, feature)
    #normalize gram matrix
    num_elements = feature.shape[0]*feature.shape[1]
    return feature/num_elements
    #return torch.einsum("bfhw,bghw->fg", feature, feature)

# %% [markdown]
# Then, incorporate it into our loss function. This only involves to changes which I will mark with a comment.

# %%
class NST_Loss(nn.Module):
    def __init__(
            self, 
            p: Tensor, 
            a: Tensor, 
            p_layers: List, 
            a_layers: List,
            alpha: float = 1.0, 
            beta: float = 1.0 #
            ):
        super().__init__()

        self.alpha = alpha
        self.beta = beta

        self.vgg19 = models.vgg19(weights=models.VGG19_Weights.IMAGENET1K_V1)
        self.vgg19.eval() 
        self.vgg19.to(device) 

        for param in self.vgg19.features.parameters():
            param.requires_grad = False

        p = p[None,...]
        a = a[None,...]
        
        self.get_layer_output_p = Get_Layer_Output()
        self.get_layer_output_a = Get_Layer_Output()
        for layer in self.vgg19.features.children():
            if not p_layers and not a_layers:
                break 
            if isinstance(layer, torch.nn.modules.conv.Conv2d):
                if p_layers and layer == self.vgg19.features[p_layers[0]]:
                    layer.register_forward_hook(self.get_layer_output_p)
                    p_layers.pop(0)
                elif a_layers and layer == self.vgg19.features[a_layers[0]]:#
                    layer.register_forward_hook(self.get_layer_output_a)
                    a_layers.pop(0)
        
        dummy_out = self.vgg19(p) 
        self.p_features = self.get_layer_output_p.outputs 
        self.num_p_layers = len(self.p_features)
        self.get_layer_output_a.clear() 
        dummy_out = self.vgg19(a) 
        self.a_features = [gram_matrix(feature) for feature in self.get_layer_output_a.outputs] #here we use the gram matrix features now
        self.num_a_layers = len(self.a_features)
        self.get_layer_output_p.clear()
        self.get_layer_output_a.clear()

    def forward(self, x: Tensor) -> Tensor:
        x = x[None,...]
        model_out = self.vgg19(x)
        p_loss = sum([(self.p_features[i] - self.get_layer_output_p.outputs[i]).pow(2).mean()*(1/self.num_p_layers) for i in range(self.num_p_layers)])
        a_loss = sum([(self.a_features[i] - gram_matrix(self.get_layer_output_a.outputs[i])).pow(2).mean()*(1/self.num_a_layers) for i in range(self.num_a_layers)]) #here we use the gram matrix features now
        self.get_layer_output_p.clear()
        self.get_layer_output_a.clear()
        return self.alpha*p_loss + self.beta*a_loss

# %% [markdown]
# Let's take another style image

# %%
x = torch.rand(3, 224, 224).to(device) 
x.requires_grad = True # to optimize it with GD
p = torchvision.io.read_image(path = "../datasets/NST/profile_pic.jpg").to(device).type(torch.float32)/255.0
a = torchvision.io.read_image(path = "../datasets/NST/lava.jpg").to(device).type(torch.float32)/255.0

#resize images to fit expected VGG dimensions
p = torchvision.transforms.functional.resize(img = p, size = [224, 224], interpolation = torchvision.transforms.InterpolationMode.BILINEAR)
a = torchvision.transforms.functional.resize(img = a, size = [224, 224], interpolation = torchvision.transforms.InterpolationMode.BILINEAR)

#show both images next to each other:
plt.figure(figsize = (10, 10))
plt.subplot(1, 3, 1)
plt.title("x: random noise")
plt.imshow(x.permute(1, 2, 0).cpu().detach().numpy())
plt.subplot(1, 3, 2)
plt.title("p: content image")
plt.imshow(p.permute(1, 2, 0).cpu().detach().numpy())
plt.subplot(1, 3, 3)
plt.title("a: style image")
plt.imshow(a.permute(1, 2, 0).cpu().detach().numpy())
# Out:
# c:\Users\s_gue\anaconda3\envs\ml_basics\Lib\site-packages\torchvision\transforms\functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
#Again normalize the images
transform = torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
x = transform(x)
p = transform(p)
a = transform(a)

# %%
model = NST_model(x, p, a, alpha = 1.0, beta = 0.2, lr = 0.05)
dataset = NST_dataset()
trainer = pl.Trainer(max_epochs=500, callbacks=[Show_Result()])
dataloader = DataLoader(dataset, batch_size=1)
trainer.fit(model, dataloader)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name         | Type     | Params
# ------------------------------------------
# 0 | NST_loss     | NST_Loss | 143 M
#   | other params | n/a      | 150 K
# ------------------------------------------
# 123 M     Trainable params
# 20.0 M    Non-trainable params
# 143 M     Total params
# 575.271   Total estimated model params size (MB)
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s] tensor(15.2751, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 1:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(12.2565, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 2:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(11.0331, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 3:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(10.3772, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 4:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(9.8848, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 5:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(9.4471, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 6:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(9.0362, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(8.6442, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 8:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(8.2809, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(7.9414, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 10:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]       tensor(7.6162, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 11:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(7.2978, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 12:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(6.9934, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 13:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(6.7136, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(6.4475, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(6.1925, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 16:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(5.9558, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 17:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(5.7321, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(5.5165, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 19:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(5.3128, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 20:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(5.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 21:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.9481, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 22:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.7810, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 23:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.6241, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 24:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.4736, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 25:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.3314, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 26:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.1952, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 27:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(4.0654, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.9403, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 29:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.8242, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 30:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.7165, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 31:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.6159, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 32:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.5208, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 33:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.4304, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 34:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.3434, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.2578, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 36:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.1761, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 37:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.0979, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 38:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(3.0236, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 39:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.9539, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 40:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.8891, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 41:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.8269, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 42:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.7669, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.7099, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 44:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.6566, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 45:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.6050, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 46:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.5553, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.5084, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 48:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.4636, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 49:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.4200, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.3784, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 51:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.3382, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 52:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.2994, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 53:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.2620, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 54:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.2257, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 55:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.1903, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 56:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.1557, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.1218, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 58:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.0895, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 59:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.0581, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 60:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(2.0278, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 61:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.9991, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 62:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.9718, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 63:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.9454, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.9196, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 65:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.8946, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 66:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.8708, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 67:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.8475, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 68:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.8249, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 69:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.8030, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 70:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.7605, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.7401, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 73:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.7204, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 74:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.7017, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 75:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.6829, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 76:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.6642, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 77:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.6462, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.6287, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 79:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.6116, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 80:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5951, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 81:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5789, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 82:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5635, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 83:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5482, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 84:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5332, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 85:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5186, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 86:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.5045, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 87:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 88:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4770, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 89:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4638, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 90:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4509, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 91:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4384, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 92:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4262, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4143, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 94:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.4025, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 95:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3910, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 96:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3799, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 97:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 98:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3577, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 99:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3467, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 100:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]       tensor(1.3361, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 101:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3258, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 102:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3157, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 103:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.3057, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 104:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2960, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 105:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2866, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 106:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2774, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 107:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2682, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 108:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2593, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 109:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2505, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 110:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2420, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 111:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2336, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 112:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2253, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 113:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2172, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 114:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2091, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 115:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.2012, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 116:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1934, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 117:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1857, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 118:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1782, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 119:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1707, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 120:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1636, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 121:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1565, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 122:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1495, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 123:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1424, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 124:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1356, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 125:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1288, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 126:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1223, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 127:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1157, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 128:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1091, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 129:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.1026, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 130:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0962, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 131:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0900, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 132:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0839, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 133:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0779, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 134:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 135:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0661, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 136:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0603, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 137:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0546, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 138:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0491, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 139:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0435, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 140:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0380, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 141:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0325, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch 142:   0%|          | 0/1 [00:00<?, ?it/s, v_num=77]        tensor(1.0272, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch